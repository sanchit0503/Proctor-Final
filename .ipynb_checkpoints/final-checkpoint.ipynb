# %%
from video_analysis import face_verification,video_analysis
# Out:
# Using cache found in C:\Users\lenovo/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2021-11-11 torch 1.10.0+cpu CPU
#
# Fusing layers...
# Model Summary: 290 layers, 21172173 parameters, 0 gradients
# Adding AutoShape...

# %%
from video_to_text import video_to_text
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import time

# %%
import shutil
import os

# %%
from location import get_location

# %%
st = time.time()

# %% [markdown]
# ## Location Access

# %%
get_location()
# Out:
# 'North Delhi,Delhi'

# %% [markdown]
# ## Video to Text

# %%
videopath = "https://feed-resources-dev.s3.ap-south-1.amazonaws.com/temp/WIN_20211118_17_49_03_Pro.mp4"

# %%
video_folder = videopath.split('/')[-1].split(".")[0]

# %%
video_folder_path = os.path.join(os.getcwd(), video_folder)

# %%
print(video_folder_path)
# Out:
# C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro

# %%
try:
    os.mkdir(video_folder_path)
except:
    print("Path already exists")

# %%
video_to_text(videopath,video_folder_path)
# Out:
# MoviePy - Writing audio in C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\audio.wav
# MoviePy - Done.
# Converted the video successfully to audio
# exporting 0.wav
# exporting 1.wav
# exporting 2.wav
# Successfully Converted the audio to chunks
# Text file saved successfully

# %% [markdown]
# ## Face Matching

# %%
face_img = './sanchit.jpg'
check_rate = 10

# %%
face_verification(face_img,videopath,video_folder_path,check_rate)
# Out:
# 6 records saved
# Done till 1875 frames
# 56.42 seconds elapsed
#
#
# Task Finished in 56 seconds

# %% [markdown]
# ## Video Analysis

# %%
check_rate = 1

# %%
video_analysis(videopath,video_folder_path,check_rate)
# Out:
# 10 records saved
# Done till 282 frames
# 12.35 seconds elapsed
#
#
# 20 records saved
# Done till 599 frames
# 23.0 seconds elapsed
#
#
# 30 records saved
# Done till 874 frames
# 33.31 seconds elapsed
#
#
# 40 records saved
# Done till 1186 frames
# 44.28 seconds elapsed
#
#
# 50 records saved
# Done till 1495 frames
# 55.85 seconds elapsed
#
#
# 60 records saved
# Done till 1800 frames
# 67.77 seconds elapsed
#
#
# 62 records saved
# Done till 1875 frames
# 69.92 seconds elapsed
#
#
# Task Finished in 70 seconds

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Saving the Suspected text in a different file

# %%
kw = ['hi', 'hello' ,'question','answer','konsa','batade','bol','kya keh raha hai','thik se bata','how','what','first','second','last','solution',
    'please repeat','which question' , 'bata na' , 'bata','kya','jaldi','thik','ek','acha']

# %%
text_filepath = os.path.join(video_folder_path,"audio_text.txt")

# %%
sentences = []

with open(text_filepath,'r') as f:
    sentences = f.readlines()

# %%
suspected_text_filepath = os.path.join(video_folder_path,"suspected.txt")
open(suspected_text_filepath, 'w').close() ##deleting the content of text file if it exists

# %%
for s in sentences:
    for k in kw:
        if k in s.lower().strip().split():
            with open(suspected_text_filepath,'a') as f:
                
                f.write(s)
                f.write("\n")
            print(s)
            print()
            break

# %%
## function to copy a frame from one folder to another
def copy_frame(old_folder,new_folder,frame):
    frame_name = "Frame_{}.jpg".format(frame)
    
    frame_path = os.path.join(old_folder,frame_name)
    shutil.copy(frame_path,new_folder)
    print("Frame Saved at {}".format(os.path.join(new_folder,frame_name)))

# %%
### function to save frames given in a dataframe to a new folder
def filter_df_save_frames(filtered_df,video_folder_path,new_folder_path,new_folder_name):
    
    new_folder_path = os.path.join(new_folder_path,new_folder_name)    
    try:
        os.mkdir(new_folder_path)
    except:
        pass
    
    old_folder_path = os.path.join(video_folder_path,"All Frames")
    
    for frame in filtered_df['frame']:
        
        copy_frame(old_folder_path, new_folder_path, frame)

# %%
vid_insights_filepath = os.path.join(video_folder_path,"vid_insights.csv")

# %%
df = pd.read_csv(vid_insights_filepath)

# %%
df.head()
# Out:
#    Unnamed: 0  frame  timestamp      Head Position  \
# 0           0     29       0.93        ['Forward']
# 1           1     33       1.07        ['Forward']
# 2           2     89       2.93        ['Forward']
# 3           3    108       3.57        ['Forward']
# 4           4    141       4.67  ['No Face Found']
#
#                                     Objects         Liveliness  \
# 0      ['person', 'bottle', 'remote', 'tv']           ['Real']
# 1      ['person', 'bottle', 'tv', 'remote']           ['Real']
# 2      ['person', 'bottle', 'tv', 'remote']           ['Real']
# 3  ['person', 'cell phone', 'bottle', 'tv']           ['Real']
# 4      ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
#
#                                      Eye Movement Shoulder Movement
# 0    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 1    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 2    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 3  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 4                        ['Eye Looking Straight']            Stable

# %% [markdown]
# ## Head Movement

# %%
df['Head Position'].value_counts()
# Out:
# ['Forward']          46
# ['Left', 'Up']        6
# ['No Face Found']     3
# ['Left']              3
# ['Down']              2
# ['Right', 'Up']       1
# ['Right']             1
# Name: Head Position, dtype: int64

# %%
## function to find the ratio of a particular value in a particular column

# %%
def get_val_ratio(col,val):
    c = 0
    for row in col:
        if val in row:
            c += 1
            
    return round(c/len(col),2)

# %%
get_val_ratio(df['Head Position'],'Right')
# Out:
# 0.03

# %%
all_scenarios = os.path.join(video_folder_path,"All Scenarios")
try:
    os.mkdir(all_scenarios)
except:
    pass

# %%
right = df.loc[df['Head Position'].apply(lambda x: "Right" in x)]

# %%
right
# Out:
#     Unnamed: 0  frame  timestamp    Head Position  \
# 22           2    672      22.37  ['Right', 'Up']
# 32           2    966      32.16        ['Right']
#
#                                  Objects         Liveliness  \
# 22  ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 32            ['person', 'bottle', 'tv']  ['No Face Found']
#
#                                     Eye Movement Shoulder Movement
# 22                      ['Eye Looking Straight']            Stable
# 32  ['Eye Looking left', 'Eye Looking Straight']            Stable

# %%
filter_df_save_frames(right,video_folder_path,all_scenarios,"Head Right")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Right\Frame_672.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Right\Frame_966.jpg

# %%
get_val_ratio(df['Head Position'],'Left')
# Out:
# 0.15

# %%
left = df.loc[df['Head Position'].apply(lambda x: "Left" in x)]
left
# Out:
#     Unnamed: 0  frame  timestamp   Head Position  \
# 10           0    329      10.93  ['Left', 'Up']
# 11           1    359      11.94  ['Left', 'Up']
# 12           2    383      12.74  ['Left', 'Up']
# 13           3    412      13.70  ['Left', 'Up']
# 14           4    450      14.96  ['Left', 'Up']
# 15           5    470      15.63  ['Left', 'Up']
# 19           9    599      19.94        ['Left']
# 20           0    610      20.30        ['Left']
# 30           0    902      30.03        ['Left']
#
#                                            Objects         Liveliness  \
# 10            ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 11            ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 12            ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 13                      ['person', 'bottle', 'tv']  ['No Face Found']
# 14            ['person', 'remote', 'tv', 'bottle']  ['No Face Found']
# 15                                ['person', 'tv']  ['No Face Found']
# 19            ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 20            ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 30  ['person', 'person', 'bottle', 'remote', 'tv']  ['No Face Found']
#
#                                       Eye Movement Shoulder Movement
# 10  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 11    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 12   ['Eye Looking right', 'Eye Looking Downward']            Stable
# 13                        ['Eye Looking Straight']            Stable
# 14                        ['Eye Looking Straight']            Stable
# 15                        ['Eye Looking Straight']            Stable
# 19  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 20                        ['Eye Looking Straight']            Stable
# 30   ['Eye Looking right', 'Eye Looking Downward']            Stable

# %%
filter_df_save_frames(left,video_folder_path,all_scenarios,"Head Left")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Left\Frame_329.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Left\Frame_359.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Left\Frame_383.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Left\Frame_412.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Left\Frame_450.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Left\Frame_470.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Left\Frame_599.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Left\Frame_610.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Head Left\Frame_902.jpg

# %%
get_val_ratio(df['Head Position'],'Down')
# Out:
# 0.03

# %%
down = df.loc[df['Head Position'].apply(lambda x : "left" in x)]
down
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, frame, timestamp, Head Position, Objects, Liveliness, Eye Movement, Shoulder Movement]
# Index: []

# %%
filter_df_save_frames(down,video_folder_path,all_scenarios,"Head Down")

# %% [markdown]
# ## Eye Movement

# %%
df['Eye Movement'].value_counts()
# Out:
# ['Eye Looking Straight']                          23
# ['Eye Looking left', 'Eye Looking Straight']      16
# ['Eye Looking center', 'Eye Looking Straight']    10
# ['Eye Looking left', 'Eye Looking Downward']       6
# ['Eye Looking left', 'Eye Looking Upward']         3
# ['Eye Looking right', 'Eye Looking Downward']      2
# ['Eye Looking center', 'Eye Looking Upward']       1
# ['Eye Looking center', 'Eye Looking Downward']     1
# Name: Eye Movement, dtype: int64

# %%
eye_left = df.loc[df['Eye Movement'].apply(lambda x: "left" in x)]
eye_left
# Out:
#     Unnamed: 0  frame  timestamp   Head Position  \
# 0            0     29       0.93     ['Forward']
# 1            1     33       1.07     ['Forward']
# 2            2     89       2.93     ['Forward']
# 5            5    164       5.44     ['Forward']
# 6            6    202       6.70     ['Forward']
# 11           1    359      11.94  ['Left', 'Up']
# 16           6    496      16.50     ['Forward']
# 17           7    511      16.99     ['Forward']
# 18           8    548      18.24        ['Down']
# 23           3    694      23.10     ['Forward']
# 25           5    751      24.99     ['Forward']
# 27           7    831      27.66     ['Forward']
# 28           8    854      28.43     ['Forward']
# 29           9    874      29.10     ['Forward']
# 31           1    945      31.47     ['Forward']
# 32           2    966      32.16       ['Right']
# 42           2   1286      42.83     ['Forward']
# 48           8   1466      48.83     ['Forward']
# 49           9   1495      49.79     ['Forward']
# 51           1   1552      51.70     ['Forward']
# 52           2   1571      52.34     ['Forward']
# 53           3   1607      53.54     ['Forward']
# 54           4   1646      54.83     ['Forward']
# 55           5   1657      55.20     ['Forward']
# 61           1   1836      61.17     ['Forward']
#
#                                               Objects         Liveliness  \
# 0                ['person', 'bottle', 'remote', 'tv']           ['Real']
# 1                ['person', 'bottle', 'tv', 'remote']           ['Real']
# 2                ['person', 'bottle', 'tv', 'remote']           ['Real']
# 5                          ['person', 'bottle', 'tv']           ['Real']
# 6                          ['person', 'bottle', 'tv']           ['Real']
# 11               ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 16               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 17               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 18               ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 23               ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 25               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 27               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 28                         ['person', 'bottle', 'tv']           ['Real']
# 29     ['person', 'bottle', 'remote', 'tv', 'person']           ['Real']
# 31               ['person', 'person', 'bottle', 'tv']           ['Real']
# 32                         ['person', 'bottle', 'tv']  ['No Face Found']
# 42  ['person', 'bottle', 'person', 'remote', 'tv',...           ['Real']
# 48  ['person', 'bottle', 'cell phone', 'person', '...           ['Real']
# 49                 ['person', 'bottle', 'cell phone']           ['Real']
# 51  ['person', 'bottle', 'chair', 'tv', 'remote', ...           ['Real']
# 52  ['person', 'bottle', 'chair', 'remote', 'tv', ...           ['Real']
# 53  ['person', 'bottle', 'person', 'tv', 'remote',...           ['Real']
# 54  ['person', 'bottle', 'tv', 'remote', 'remote',...  ['No Face Found']
# 55  ['person', 'bottle', 'chair', 'tv', 'remote', ...           ['Real']
# 61  ['person', 'bottle', 'chair', 'person', 'remot...           ['Real']
#
#                                     Eye Movement Shoulder Movement
# 0   ['Eye Looking left', 'Eye Looking Straight']            Stable
# 1   ['Eye Looking left', 'Eye Looking Straight']            Stable
# 2   ['Eye Looking left', 'Eye Looking Straight']            Stable
# 5   ['Eye Looking left', 'Eye Looking Straight']            Stable
# 6   ['Eye Looking left', 'Eye Looking Downward']            Stable
# 11  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 16  ['Eye Looking left', 'Eye Looking Downward']            Stable
# 17  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 18  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 23  ['Eye Looking left', 'Eye Looking Downward']            Stable
# 25  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 27  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 28  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 29  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 31  ['Eye Looking left', 'Eye Looking Downward']            Stable
# 32  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 42    ['Eye Looking left', 'Eye Looking Upward']            Stable
# 48  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 49  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 51    ['Eye Looking left', 'Eye Looking Upward']            Stable
# 52  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 53    ['Eye Looking left', 'Eye Looking Upward']            Stable
# 54  ['Eye Looking left', 'Eye Looking Downward']            Stable
# 55  ['Eye Looking left', 'Eye Looking Downward']            Stable
# 61  ['Eye Looking left', 'Eye Looking Straight']            Stable

# %%
filter_df_save_frames(eye_left,video_folder_path,all_scenarios,"Eye Left")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_29.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_33.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_89.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_164.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_202.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_359.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_496.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_511.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_548.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_694.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_751.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_831.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_854.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_874.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_945.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_966.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_1286.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_1466.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_1495.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_1552.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_1571.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_1607.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_1646.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_1657.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Left\Frame_1836.jpg

# %%
eye_right = df.loc[df['Eye Movement'].apply(lambda x: "right" in x)]
eye_right
# Out:
#     Unnamed: 0  frame  timestamp   Head Position  \
# 12           2    383      12.74  ['Left', 'Up']
# 30           0    902      30.03        ['Left']
#
#                                            Objects         Liveliness  \
# 12            ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 30  ['person', 'person', 'bottle', 'remote', 'tv']  ['No Face Found']
#
#                                      Eye Movement Shoulder Movement
# 12  ['Eye Looking right', 'Eye Looking Downward']            Stable
# 30  ['Eye Looking right', 'Eye Looking Downward']            Stable

# %%
filter_df_save_frames(eye_right,video_folder_path,all_scenarios,"Eye Right")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Right\Frame_383.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Right\Frame_902.jpg

# %%
eye_up = df.loc[df['Eye Movement'].apply(lambda x: "Upward" in x)]
eye_up
# Out:
#     Unnamed: 0  frame  timestamp Head Position  \
# 41           1   1245      41.47   ['Forward']
# 42           2   1286      42.83   ['Forward']
# 51           1   1552      51.70   ['Forward']
# 53           3   1607      53.54   ['Forward']
#
#                                               Objects Liveliness  \
# 41  ['cell phone', 'bottle', 'person', 'chair', 'r...   ['Real']
# 42  ['person', 'bottle', 'person', 'remote', 'tv',...   ['Real']
# 51  ['person', 'bottle', 'chair', 'tv', 'remote', ...   ['Real']
# 53  ['person', 'bottle', 'person', 'tv', 'remote',...   ['Real']
#
#                                     Eye Movement Shoulder Movement
# 41  ['Eye Looking center', 'Eye Looking Upward']            Moving
# 42    ['Eye Looking left', 'Eye Looking Upward']            Stable
# 51    ['Eye Looking left', 'Eye Looking Upward']            Stable
# 53    ['Eye Looking left', 'Eye Looking Upward']            Stable

# %%
filter_df_save_frames(eye_up,video_folder_path,all_scenarios,"Eye Upward")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Upward\Frame_1245.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Upward\Frame_1286.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Upward\Frame_1552.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Upward\Frame_1607.jpg

# %%
eye_downward = df.loc[df['Eye Movement'].apply(lambda x: "Upward" in x)]
eye_downward
# Out:
#     Unnamed: 0  frame  timestamp Head Position  \
# 41           1   1245      41.47   ['Forward']
# 42           2   1286      42.83   ['Forward']
# 51           1   1552      51.70   ['Forward']
# 53           3   1607      53.54   ['Forward']
#
#                                               Objects Liveliness  \
# 41  ['cell phone', 'bottle', 'person', 'chair', 'r...   ['Real']
# 42  ['person', 'bottle', 'person', 'remote', 'tv',...   ['Real']
# 51  ['person', 'bottle', 'chair', 'tv', 'remote', ...   ['Real']
# 53  ['person', 'bottle', 'person', 'tv', 'remote',...   ['Real']
#
#                                     Eye Movement Shoulder Movement
# 41  ['Eye Looking center', 'Eye Looking Upward']            Moving
# 42    ['Eye Looking left', 'Eye Looking Upward']            Stable
# 51    ['Eye Looking left', 'Eye Looking Upward']            Stable
# 53    ['Eye Looking left', 'Eye Looking Upward']            Stable

# %%
filter_df_save_frames(eye_downward,video_folder_path,all_scenarios,"Eye Downward")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Downward\Frame_1245.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Downward\Frame_1286.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Downward\Frame_1552.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Eye Downward\Frame_1607.jpg

# %%
get_val_ratio(df['Eye Movement'],'Eye Looking left')
# Out:
# 0.4

# %%
get_val_ratio(df['Eye Movement'],'Eye Looking right')
# Out:
# 0.03

# %%
get_val_ratio(df['Eye Movement'],'Eye Looking Downward')
# Out:
# 0.15

# %% [markdown]
# ## Object Detection

# %%
df['Objects'].value_counts()
# Out:
# ['person', 'bottle', 'tv', 'remote']                                         13
# ['person', 'bottle', 'tv']                                                    9
# ['person', 'bottle', 'remote', 'tv']                                          8
# ['person', 'bottle', 'person', 'tv', 'remote', 'remote']                      2
# ['person', 'bottle', 'chair', 'tv', 'person', 'remote', 'remote']             1
# ['person', 'bottle', 'tv', 'chair', 'person', 'remote', 'remote']             1
# ['person', 'bottle', 'chair', 'tv', 'person']                                 1
# ['person', 'bottle', 'chair', 'remote', 'tv', 'person', 'remote']             1
# ['person', 'bottle', 'chair', 'tv', 'remote', 'person', 'remote']             1
# ['person', 'bottle', 'chair', 'tv', 'remote', 'remote']                       1
# ['person', 'bottle', 'person', 'chair', 'remote', 'tv']                       1
# ['person', 'bottle', 'chair', 'remote', 'tv', 'person']                       1
# ['person', 'bottle', 'chair', 'tv', 'remote', 'toothbrush']                   1
# ['person', 'bottle', 'cell phone', 'person', 'tv', 'chair', 'couch']          1
# ['person', 'bottle', 'cell phone']                                            1
# ['person', 'bottle', 'cell phone', 'person', 'remote', 'tv']                  1
# ['person', 'bottle', 'toothbrush', 'person', 'remote', 'remote']              1
# ['person', 'bottle', 'tv', 'remote', 'remote', 'chair', 'person']             1
# ['person', 'bottle', 'person', 'remote']                                      1
# ['person', 'bottle', 'person', 'tv', 'chair', 'remote', 'remote']             1
# ['person', 'bottle', 'person', 'remote', 'tv', 'remote', 'remote']            1
# ['cell phone', 'bottle', 'person', 'chair', 'remote', 'remote', 'remote']     1
# ['person', 'bottle', 'oven']                                                  1
# ['person', 'person', 'bottle']                                                1
# ['person', 'person', 'person', 'person', 'person', 'tie']                     1
# ['person', 'bottle']                                                          1
# ['person', 'person', 'bottle', 'tv']                                          1
# ['person', 'person', 'bottle', 'remote', 'tv']                                1
# ['person', 'bottle', 'remote', 'tv', 'person']                                1
# ['person', 'tv', 'remote']                                                    1
# ['person', 'tv']                                                              1
# ['person', 'remote', 'tv', 'bottle']                                          1
# ['person', 'cell phone', 'bottle', 'tv']                                      1
# ['person', 'bottle', 'chair', 'person', 'remote', 'remote', 'tv']             1
# Name: Objects, dtype: int64

# %%
get_val_ratio(df['Objects'],'person')
# Out:
# 1.0

# %% [markdown]
# ### To check for presence of cell phone in video

# %%
get_val_ratio(df['Objects'],'cell phone')
# Out:
# 0.08

# %%
cell_phone = df.loc[df['Objects'].apply(lambda x:"cell phone" in x)]
cell_phone
# Out:
#     Unnamed: 0  frame  timestamp Head Position  \
# 3            3    108       3.57   ['Forward']
# 41           1   1245      41.47   ['Forward']
# 48           8   1466      48.83   ['Forward']
# 49           9   1495      49.79   ['Forward']
# 50           0   1523      50.74   ['Forward']
#
#                                               Objects Liveliness  \
# 3            ['person', 'cell phone', 'bottle', 'tv']   ['Real']
# 41  ['cell phone', 'bottle', 'person', 'chair', 'r...   ['Real']
# 48  ['person', 'bottle', 'cell phone', 'person', '...   ['Real']
# 49                 ['person', 'bottle', 'cell phone']   ['Real']
# 50  ['person', 'bottle', 'cell phone', 'person', '...   ['Real']
#
#                                       Eye Movement Shoulder Movement
# 3   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 41    ['Eye Looking center', 'Eye Looking Upward']            Moving
# 48    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 49    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 50  ['Eye Looking center', 'Eye Looking Straight']            Moving

# %%
filter_df_save_frames(cell_phone,video_folder_path,all_scenarios,"Cell Phone Present")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Cell Phone Present\Frame_108.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Cell Phone Present\Frame_1245.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Cell Phone Present\Frame_1466.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Cell Phone Present\Frame_1495.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Cell Phone Present\Frame_1523.jpg

# %% [markdown]
# ### No person

# %%
np = df.loc[df['Objects'].apply(lambda x: x.count("person") == 0)]
np
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, frame, timestamp, Head Position, Objects, Liveliness, Eye Movement, Shoulder Movement]
# Index: []

# %%
filter_df_save_frames(np,video_folder_path,all_scenarios,"No Person")

# %% [markdown]
# ### More than One Person

# %%
mp = df.loc[df['Objects'].apply(lambda x: x.count('person')>1)]
mp
# Out:
#     Unnamed: 0  frame  timestamp      Head Position  \
# 29           9    874      29.10        ['Forward']
# 30           0    902      30.03           ['Left']
# 31           1    945      31.47        ['Forward']
# 38           8   1170      38.96  ['No Face Found']
# 39           9   1186      39.50        ['Forward']
# 42           2   1286      42.83        ['Forward']
# 43           3   1307      43.54        ['Forward']
# 44           4   1327      44.19        ['Forward']
# 45           5   1352      45.02        ['Forward']
# 46           6   1381      46.00        ['Forward']
# 47           7   1436      47.82        ['Forward']
# 48           8   1466      48.83        ['Forward']
# 50           0   1523      50.74        ['Forward']
# 52           2   1571      52.34        ['Forward']
# 53           3   1607      53.54        ['Forward']
# 54           4   1646      54.83        ['Forward']
# 56           6   1706      56.83        ['Forward']
# 57           7   1715      57.14        ['Forward']
# 58           8   1742      58.03        ['Forward']
# 59           9   1800      59.97        ['Forward']
# 60           0   1809      60.27        ['Forward']
# 61           1   1836      61.17        ['Forward']
#
#                                               Objects         Liveliness  \
# 29     ['person', 'bottle', 'remote', 'tv', 'person']           ['Real']
# 30     ['person', 'person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 31               ['person', 'person', 'bottle', 'tv']           ['Real']
# 38  ['person', 'person', 'person', 'person', 'pers...  ['No Face Found']
# 39                     ['person', 'person', 'bottle']           ['Real']
# 42  ['person', 'bottle', 'person', 'remote', 'tv',...           ['Real']
# 43  ['person', 'bottle', 'person', 'tv', 'chair', ...           ['Real']
# 44           ['person', 'bottle', 'person', 'remote']           ['Real']
# 45  ['person', 'bottle', 'person', 'chair', 'remot...           ['Real']
# 46  ['person', 'bottle', 'person', 'tv', 'remote',...           ['Real']
# 47  ['person', 'bottle', 'toothbrush', 'person', '...           ['Real']
# 48  ['person', 'bottle', 'cell phone', 'person', '...           ['Real']
# 50  ['person', 'bottle', 'cell phone', 'person', '...           ['Real']
# 52  ['person', 'bottle', 'chair', 'remote', 'tv', ...           ['Real']
# 53  ['person', 'bottle', 'person', 'tv', 'remote',...           ['Real']
# 54  ['person', 'bottle', 'tv', 'remote', 'remote',...  ['No Face Found']
# 56  ['person', 'bottle', 'chair', 'tv', 'remote', ...           ['Real']
# 57  ['person', 'bottle', 'chair', 'remote', 'tv', ...           ['Real']
# 58      ['person', 'bottle', 'chair', 'tv', 'person']           ['Real']
# 59  ['person', 'bottle', 'tv', 'chair', 'person', ...           ['Real']
# 60  ['person', 'bottle', 'chair', 'tv', 'person', ...           ['Real']
# 61  ['person', 'bottle', 'chair', 'person', 'remot...           ['Real']
#
#                                       Eye Movement Shoulder Movement
# 29    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 30   ['Eye Looking right', 'Eye Looking Downward']            Stable
# 31    ['Eye Looking left', 'Eye Looking Downward']            Stable
# 38                        ['Eye Looking Straight']            Moving
# 39                        ['Eye Looking Straight']            Moving
# 42      ['Eye Looking left', 'Eye Looking Upward']            Stable
# 43                        ['Eye Looking Straight']            Stable
# 44                        ['Eye Looking Straight']            Stable
# 45                        ['Eye Looking Straight']            Stable
# 46  ['Eye Looking center', 'Eye Looking Downward']            Stable
# 47                        ['Eye Looking Straight']            Stable
# 48    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 50  ['Eye Looking center', 'Eye Looking Straight']            Moving
# 52    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 53      ['Eye Looking left', 'Eye Looking Upward']            Stable
# 54    ['Eye Looking left', 'Eye Looking Downward']            Stable
# 56                        ['Eye Looking Straight']            Stable
# 57                        ['Eye Looking Straight']            Stable
# 58                        ['Eye Looking Straight']            Stable
# 59                        ['Eye Looking Straight']            Stable
# 60                        ['Eye Looking Straight']            Stable
# 61    ['Eye Looking left', 'Eye Looking Straight']            Stable

# %%
filter_df_save_frames(mp,video_folder_path,all_scenarios,"More than one Person")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_874.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_902.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_945.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1170.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1186.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1286.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1307.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1327.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1352.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1381.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1436.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1466.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1523.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1571.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1607.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1646.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1706.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1715.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1742.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1800.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1809.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\More than one Person\Frame_1836.jpg

# %% [markdown]
# ### Spoof Images

# %%
df['Liveliness'].value_counts()
# Out:
# ['Real']             45
# ['No Face Found']    17
# Name: Liveliness, dtype: int64

# %%
spoof = df.loc[df['Liveliness'].apply(lambda x: "Spoof" in x)]

# %%
filter_df_save_frames(spoof,video_folder_path,all_scenarios,"Spoof Images")

# %% [markdown]
# ## Shoulder Stable but  Eye Down

# %%
ss = df.loc[(df['Shoulder Movement'] == "Stable") & (df['Eye Movement'].apply(lambda x: "Downward" in x))]

# %%
filter_df_save_frames(ss,video_folder_path,all_scenarios,"Shoulder Stable Eye Down")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Down\Frame_202.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Down\Frame_383.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Down\Frame_496.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Down\Frame_694.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Down\Frame_902.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Down\Frame_945.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Down\Frame_1381.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Down\Frame_1646.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Down\Frame_1657.jpg

# %% [markdown]
# ## Shoulder Stable Eye Left

# %%
sl = df.loc[(df['Shoulder Movement'] == "Stable") & (df['Eye Movement'].apply(lambda x: "left" in x))]

# %%
sl
# Out:
#     Unnamed: 0  frame  timestamp   Head Position  \
# 0            0     29       0.93     ['Forward']
# 1            1     33       1.07     ['Forward']
# 2            2     89       2.93     ['Forward']
# 5            5    164       5.44     ['Forward']
# 6            6    202       6.70     ['Forward']
# 11           1    359      11.94  ['Left', 'Up']
# 16           6    496      16.50     ['Forward']
# 17           7    511      16.99     ['Forward']
# 18           8    548      18.24        ['Down']
# 23           3    694      23.10     ['Forward']
# 25           5    751      24.99     ['Forward']
# 27           7    831      27.66     ['Forward']
# 28           8    854      28.43     ['Forward']
# 29           9    874      29.10     ['Forward']
# 31           1    945      31.47     ['Forward']
# 32           2    966      32.16       ['Right']
# 42           2   1286      42.83     ['Forward']
# 48           8   1466      48.83     ['Forward']
# 49           9   1495      49.79     ['Forward']
# 51           1   1552      51.70     ['Forward']
# 52           2   1571      52.34     ['Forward']
# 53           3   1607      53.54     ['Forward']
# 54           4   1646      54.83     ['Forward']
# 55           5   1657      55.20     ['Forward']
# 61           1   1836      61.17     ['Forward']
#
#                                               Objects         Liveliness  \
# 0                ['person', 'bottle', 'remote', 'tv']           ['Real']
# 1                ['person', 'bottle', 'tv', 'remote']           ['Real']
# 2                ['person', 'bottle', 'tv', 'remote']           ['Real']
# 5                          ['person', 'bottle', 'tv']           ['Real']
# 6                          ['person', 'bottle', 'tv']           ['Real']
# 11               ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 16               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 17               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 18               ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 23               ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 25               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 27               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 28                         ['person', 'bottle', 'tv']           ['Real']
# 29     ['person', 'bottle', 'remote', 'tv', 'person']           ['Real']
# 31               ['person', 'person', 'bottle', 'tv']           ['Real']
# 32                         ['person', 'bottle', 'tv']  ['No Face Found']
# 42  ['person', 'bottle', 'person', 'remote', 'tv',...           ['Real']
# 48  ['person', 'bottle', 'cell phone', 'person', '...           ['Real']
# 49                 ['person', 'bottle', 'cell phone']           ['Real']
# 51  ['person', 'bottle', 'chair', 'tv', 'remote', ...           ['Real']
# 52  ['person', 'bottle', 'chair', 'remote', 'tv', ...           ['Real']
# 53  ['person', 'bottle', 'person', 'tv', 'remote',...           ['Real']
# 54  ['person', 'bottle', 'tv', 'remote', 'remote',...  ['No Face Found']
# 55  ['person', 'bottle', 'chair', 'tv', 'remote', ...           ['Real']
# 61  ['person', 'bottle', 'chair', 'person', 'remot...           ['Real']
#
#                                     Eye Movement Shoulder Movement
# 0   ['Eye Looking left', 'Eye Looking Straight']            Stable
# 1   ['Eye Looking left', 'Eye Looking Straight']            Stable
# 2   ['Eye Looking left', 'Eye Looking Straight']            Stable
# 5   ['Eye Looking left', 'Eye Looking Straight']            Stable
# 6   ['Eye Looking left', 'Eye Looking Downward']            Stable
# 11  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 16  ['Eye Looking left', 'Eye Looking Downward']            Stable
# 17  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 18  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 23  ['Eye Looking left', 'Eye Looking Downward']            Stable
# 25  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 27  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 28  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 29  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 31  ['Eye Looking left', 'Eye Looking Downward']            Stable
# 32  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 42    ['Eye Looking left', 'Eye Looking Upward']            Stable
# 48  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 49  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 51    ['Eye Looking left', 'Eye Looking Upward']            Stable
# 52  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 53    ['Eye Looking left', 'Eye Looking Upward']            Stable
# 54  ['Eye Looking left', 'Eye Looking Downward']            Stable
# 55  ['Eye Looking left', 'Eye Looking Downward']            Stable
# 61  ['Eye Looking left', 'Eye Looking Straight']            Stable

# %%
filter_df_save_frames(sl,video_folder_path,all_scenarios,"Shoulder Stable Eye Left")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_29.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_33.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_89.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_164.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_202.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_359.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_496.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_511.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_548.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_694.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_751.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_831.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_854.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_874.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_945.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_966.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_1286.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_1466.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_1495.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_1552.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_1571.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_1607.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_1646.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_1657.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Left\Frame_1836.jpg

# %% [markdown]
# ### Shoulder Stable Eye Right

# %%
sr = df.loc[(df['Shoulder Movement'] == "Stable") & (df['Eye Movement'].apply(lambda x: "right" in x))]
filter_df_save_frames(sr,video_folder_path,all_scenarios,"Shoulder Stable Eye Right")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Right\Frame_383.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Eye Right\Frame_902.jpg

# %% [markdown]
# ### Shoulder Stable Head Down

# %%
sshd = df.loc[(df['Head Position'].apply(lambda x: "Down" in x)) & (df['Shoulder Movement'] == "Stable")]
sshd
# Out:
#     Unnamed: 0  frame  timestamp Head Position  \
# 18           8    548      18.24      ['Down']
# 24           4    729      24.27      ['Down']
#
#                                  Objects         Liveliness  \
# 18  ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 24  ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
#
#                                     Eye Movement Shoulder Movement
# 18  ['Eye Looking left', 'Eye Looking Straight']            Stable
# 24                      ['Eye Looking Straight']            Stable

# %%
filter_df_save_frames(sshd,video_folder_path,all_scenarios,"Shoulder Stable Head Down")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Down\Frame_548.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Down\Frame_729.jpg

# %% [markdown]
# ### Shoulder Stable Head Left

# %%
ssld = df.loc[(df['Head Position'].apply(lambda x: "Left" in x)) & (df['Shoulder Movement'] == "Stable")]
ssld
# Out:
#     Unnamed: 0  frame  timestamp   Head Position  \
# 10           0    329      10.93  ['Left', 'Up']
# 11           1    359      11.94  ['Left', 'Up']
# 12           2    383      12.74  ['Left', 'Up']
# 13           3    412      13.70  ['Left', 'Up']
# 14           4    450      14.96  ['Left', 'Up']
# 15           5    470      15.63  ['Left', 'Up']
# 19           9    599      19.94        ['Left']
# 20           0    610      20.30        ['Left']
# 30           0    902      30.03        ['Left']
#
#                                            Objects         Liveliness  \
# 10            ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 11            ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 12            ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 13                      ['person', 'bottle', 'tv']  ['No Face Found']
# 14            ['person', 'remote', 'tv', 'bottle']  ['No Face Found']
# 15                                ['person', 'tv']  ['No Face Found']
# 19            ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 20            ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 30  ['person', 'person', 'bottle', 'remote', 'tv']  ['No Face Found']
#
#                                       Eye Movement Shoulder Movement
# 10  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 11    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 12   ['Eye Looking right', 'Eye Looking Downward']            Stable
# 13                        ['Eye Looking Straight']            Stable
# 14                        ['Eye Looking Straight']            Stable
# 15                        ['Eye Looking Straight']            Stable
# 19  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 20                        ['Eye Looking Straight']            Stable
# 30   ['Eye Looking right', 'Eye Looking Downward']            Stable

# %%
filter_df_save_frames(ssld,video_folder_path,all_scenarios,"Shoulder Stable Head Left")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Left\Frame_329.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Left\Frame_359.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Left\Frame_383.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Left\Frame_412.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Left\Frame_450.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Left\Frame_470.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Left\Frame_599.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Left\Frame_610.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Left\Frame_902.jpg

# %%
ssrd = df.loc[(df['Head Position'].apply(lambda x: "Right" in x)) & (df['Shoulder Movement'] == "Stable")]
ssrd
# Out:
#     Unnamed: 0  frame  timestamp    Head Position  \
# 22           2    672      22.37  ['Right', 'Up']
# 32           2    966      32.16        ['Right']
#
#                                  Objects         Liveliness  \
# 22  ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 32            ['person', 'bottle', 'tv']  ['No Face Found']
#
#                                     Eye Movement Shoulder Movement
# 22                      ['Eye Looking Straight']            Stable
# 32  ['Eye Looking left', 'Eye Looking Straight']            Stable

# %%
filter_df_save_frames(ssrd,video_folder_path,all_scenarios,"Shoulder Stable Head Right")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Right\Frame_672.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\All Scenarios\Shoulder Stable Head Right\Frame_966.jpg

# %% [markdown]
# ## Face Not Matched

# %%
face = os.path.join(video_folder_path,"face_match.csv")

# %%
face_df = pd.read_csv(face)

# %%
fn = face_df.loc[face_df['Face Verification'] == 'Face not Matched']
fn
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, frame, timestamp, Face Verification]
# Index: []

# %%
filter_df_save_frames(fn,video_folder_path,all_scenarios,"Face Not Matched")

# %% [markdown]
# ## Analysis for Interval

# %%
def get_val_ratio_for_interval(col,val,interval_start,num_rows):
    col_subset = col.iloc[interval_start:interval_start+num_rows]
    
    return get_val_ratio(col_subset,val)

# %% [markdown]
# ### Head Left

# %%
threshold = 0.5
interval = 10
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Head Position'],'Left',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
        print(i,ratio)
# Out:
# 5 0.5
# 6 0.6
# 7 0.6
# 8 0.6
# 9 0.6
# 10 0.7
# 11 0.7
# 12 0.6
# 13 0.5

# %%
df.iloc[idx_list]
# Out:
#     Unnamed: 0  frame  timestamp   Head Position  \
# 5            5    164       5.44     ['Forward']
# 6            6    202       6.70     ['Forward']
# 7            7    211       6.99     ['Forward']
# 8            8    244       8.10     ['Forward']
# 9            9    282       9.36     ['Forward']
# 10           0    329      10.93  ['Left', 'Up']
# 11           1    359      11.94  ['Left', 'Up']
# 12           2    383      12.74  ['Left', 'Up']
# 13           3    412      13.70  ['Left', 'Up']
#
#                                  Objects         Liveliness  \
# 5             ['person', 'bottle', 'tv']           ['Real']
# 6             ['person', 'bottle', 'tv']           ['Real']
# 7             ['person', 'bottle', 'tv']           ['Real']
# 8             ['person', 'bottle', 'tv']           ['Real']
# 9             ['person', 'bottle', 'tv']           ['Real']
# 10  ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 11  ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 12  ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 13            ['person', 'bottle', 'tv']  ['No Face Found']
#
#                                       Eye Movement Shoulder Movement
# 5     ['Eye Looking left', 'Eye Looking Straight']            Stable
# 6     ['Eye Looking left', 'Eye Looking Downward']            Stable
# 7   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 8   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 9   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 10  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 11    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 12   ['Eye Looking right', 'Eye Looking Downward']            Stable
# 13                        ['Eye Looking Straight']            Stable

# %% [markdown]
# ### Head Right

# %%
threshold = 0.5
interval = 10
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Head Position'],'Right',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
        print(i,ratio)

# %%
df['Head Position'].value_counts()
# Out:
# ['Forward']          46
# ['Left', 'Up']        6
# ['No Face Found']     3
# ['Left']              3
# ['Down']              2
# ['Right', 'Up']       1
# ['Right']             1
# Name: Head Position, dtype: int64

# %% [markdown]
# ### Head Down

# %%
threshold = 0.5
interval = 10
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Head Position'],'Down',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
        print(i,ratio)

# %% [markdown]
# ### Head Up

# %%
threshold = 0.5
interval = 5
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Head Position'],'Up',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
        print(i,ratio)
# Out:
# 8 0.6
# 9 0.8
# 10 1.0
# 11 1.0
# 12 0.8
# 13 0.6

# %%
df.iloc[idx_list]
# Out:
#     Unnamed: 0  frame  timestamp   Head Position  \
# 8            8    244       8.10     ['Forward']
# 9            9    282       9.36     ['Forward']
# 10           0    329      10.93  ['Left', 'Up']
# 11           1    359      11.94  ['Left', 'Up']
# 12           2    383      12.74  ['Left', 'Up']
# 13           3    412      13.70  ['Left', 'Up']
#
#                                  Objects         Liveliness  \
# 8             ['person', 'bottle', 'tv']           ['Real']
# 9             ['person', 'bottle', 'tv']           ['Real']
# 10  ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 11  ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 12  ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 13            ['person', 'bottle', 'tv']  ['No Face Found']
#
#                                       Eye Movement Shoulder Movement
# 8   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 9   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 10  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 11    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 12   ['Eye Looking right', 'Eye Looking Downward']            Stable
# 13                        ['Eye Looking Straight']            Stable

# %% [markdown]
# ### Eye Down

# %%
threshold = 0.5
interval = 10
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Eye Movement'],'Down',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
        print(i,ratio)

# %%
df.iloc[idx_list]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, frame, timestamp, Head Position, Objects, Liveliness, Eye Movement, Shoulder Movement]
# Index: []

# %% [markdown]
# ### Eye Left

# %%
threshold = 0.5
interval = 10
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Eye Movement'],'left',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
        print(i,ratio)
# Out:
# 0 0.5
# 16 0.5
# 20 0.5
# 21 0.5
# 22 0.6
# 23 0.7
# 24 0.6
# 25 0.6
# 26 0.5
# 27 0.5
# 44 0.5
# 45 0.6
# 46 0.7
# 47 0.7
# 48 0.7
# 49 0.6
# 50 0.5
# 51 0.5
# 52 0.5
# 60 0.5
# 61 1.0

# %%
df.iloc[idx_list]
# Out:
#     Unnamed: 0  frame  timestamp    Head Position  \
# 0            0     29       0.93      ['Forward']
# 16           6    496      16.50      ['Forward']
# 20           0    610      20.30         ['Left']
# 21           1    645      21.47      ['Forward']
# 22           2    672      22.37  ['Right', 'Up']
# 23           3    694      23.10      ['Forward']
# 24           4    729      24.27         ['Down']
# 25           5    751      24.99      ['Forward']
# 26           6    794      26.43      ['Forward']
# 27           7    831      27.66      ['Forward']
# 44           4   1327      44.19      ['Forward']
# 45           5   1352      45.02      ['Forward']
# 46           6   1381      46.00      ['Forward']
# 47           7   1436      47.82      ['Forward']
# 48           8   1466      48.83      ['Forward']
# 49           9   1495      49.79      ['Forward']
# 50           0   1523      50.74      ['Forward']
# 51           1   1552      51.70      ['Forward']
# 52           2   1571      52.34      ['Forward']
# 60           0   1809      60.27      ['Forward']
# 61           1   1836      61.17      ['Forward']
#
#                                               Objects         Liveliness  \
# 0                ['person', 'bottle', 'remote', 'tv']           ['Real']
# 16               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 20               ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 21               ['person', 'bottle', 'remote', 'tv']           ['Real']
# 22               ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 23               ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 24               ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 25               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 26                         ['person', 'tv', 'remote']           ['Real']
# 27               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 44           ['person', 'bottle', 'person', 'remote']           ['Real']
# 45  ['person', 'bottle', 'person', 'chair', 'remot...           ['Real']
# 46  ['person', 'bottle', 'person', 'tv', 'remote',...           ['Real']
# 47  ['person', 'bottle', 'toothbrush', 'person', '...           ['Real']
# 48  ['person', 'bottle', 'cell phone', 'person', '...           ['Real']
# 49                 ['person', 'bottle', 'cell phone']           ['Real']
# 50  ['person', 'bottle', 'cell phone', 'person', '...           ['Real']
# 51  ['person', 'bottle', 'chair', 'tv', 'remote', ...           ['Real']
# 52  ['person', 'bottle', 'chair', 'remote', 'tv', ...           ['Real']
# 60  ['person', 'bottle', 'chair', 'tv', 'person', ...           ['Real']
# 61  ['person', 'bottle', 'chair', 'person', 'remot...           ['Real']
#
#                                       Eye Movement Shoulder Movement
# 0     ['Eye Looking left', 'Eye Looking Straight']            Stable
# 16    ['Eye Looking left', 'Eye Looking Downward']            Stable
# 20                        ['Eye Looking Straight']            Stable
# 21  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 22                        ['Eye Looking Straight']            Stable
# 23    ['Eye Looking left', 'Eye Looking Downward']            Stable
# 24                        ['Eye Looking Straight']            Stable
# 25    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 26  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 27    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 44                        ['Eye Looking Straight']            Stable
# 45                        ['Eye Looking Straight']            Stable
# 46  ['Eye Looking center', 'Eye Looking Downward']            Stable
# 47                        ['Eye Looking Straight']            Stable
# 48    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 49    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 50  ['Eye Looking center', 'Eye Looking Straight']            Moving
# 51      ['Eye Looking left', 'Eye Looking Upward']            Stable
# 52    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 60                        ['Eye Looking Straight']            Stable
# 61    ['Eye Looking left', 'Eye Looking Straight']            Stable

# %% [markdown]
# ### Eye right

# %%
df['Eye Movement'].value_counts()
# Out:
# ['Eye Looking Straight']                          23
# ['Eye Looking left', 'Eye Looking Straight']      16
# ['Eye Looking center', 'Eye Looking Straight']    10
# ['Eye Looking left', 'Eye Looking Downward']       6
# ['Eye Looking left', 'Eye Looking Upward']         3
# ['Eye Looking right', 'Eye Looking Downward']      2
# ['Eye Looking center', 'Eye Looking Upward']       1
# ['Eye Looking center', 'Eye Looking Downward']     1
# Name: Eye Movement, dtype: int64

# %%
threshold = 0.5
interval = 3
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Eye Movement'],'right',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
        print(i,ratio)

# %% [markdown]
# ### Eye Up

# %%
threshold = 0.5
interval = 5
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Eye Movement'],'Up',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
        print(i,ratio)

# %% [markdown]
# ## Cheating Scenarios

# %%
df = pd.read_csv(os.path.join(video_folder_path,"vid_insights.csv"))

# %%
cheating_scenarios = os.path.join(video_folder_path,"Cheating Scenarios")
try:
    os.mkdir(cheating_scenarios)
except:
    pass

# %%
interval = 10
threshold = 0.5

# %% [markdown]
# ### Head Left

# %%
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Head Position'],'Left',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
hl = df.iloc[idx_list]
hl
# Out:
#     Unnamed: 0  frame  timestamp   Head Position  \
# 5            5    164       5.44     ['Forward']
# 6            6    202       6.70     ['Forward']
# 7            7    211       6.99     ['Forward']
# 8            8    244       8.10     ['Forward']
# 9            9    282       9.36     ['Forward']
# 10           0    329      10.93  ['Left', 'Up']
# 11           1    359      11.94  ['Left', 'Up']
# 12           2    383      12.74  ['Left', 'Up']
# 13           3    412      13.70  ['Left', 'Up']
#
#                                  Objects         Liveliness  \
# 5             ['person', 'bottle', 'tv']           ['Real']
# 6             ['person', 'bottle', 'tv']           ['Real']
# 7             ['person', 'bottle', 'tv']           ['Real']
# 8             ['person', 'bottle', 'tv']           ['Real']
# 9             ['person', 'bottle', 'tv']           ['Real']
# 10  ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 11  ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 12  ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 13            ['person', 'bottle', 'tv']  ['No Face Found']
#
#                                       Eye Movement Shoulder Movement
# 5     ['Eye Looking left', 'Eye Looking Straight']            Stable
# 6     ['Eye Looking left', 'Eye Looking Downward']            Stable
# 7   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 8   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 9   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 10  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 11    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 12   ['Eye Looking right', 'Eye Looking Downward']            Stable
# 13                        ['Eye Looking Straight']            Stable

# %%
filter_df_save_frames(hl,video_folder_path,cheating_scenarios,"Head Left")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Left\Frame_164.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Left\Frame_202.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Left\Frame_211.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Left\Frame_244.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Left\Frame_282.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Left\Frame_329.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Left\Frame_359.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Left\Frame_383.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Left\Frame_412.jpg

# %% [markdown]
# ### Head Right

# %%
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Head Position'],'Right',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
hr = df.iloc[idx_list]
hr
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, frame, timestamp, Head Position, Objects, Liveliness, Eye Movement, Shoulder Movement]
# Index: []

# %%
filter_df_save_frames(hl,video_folder_path,cheating_scenarios,"Head Right")

# %% [markdown]
# ### Head Down

# %%
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Head Position'],'Down',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
hd = df.iloc[idx_list]
hd
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, frame, timestamp, Head Position, Objects, Liveliness, Eye Movement, Shoulder Movement]
# Index: []

# %%
filter_df_save_frames(hd,video_folder_path,cheating_scenarios,"Head Down")

# %% [markdown]
# ### Head Up

# %%
df['Head Position'].value_counts()
# Out:
# ['Forward']          46
# ['Left', 'Up']        6
# ['No Face Found']     3
# ['Left']              3
# ['Down']              2
# ['Right', 'Up']       1
# ['Right']             1
# Name: Head Position, dtype: int64

# %%
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Head Position'],'Up',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
hu = df.iloc[idx_list]
hu
# Out:
#     Unnamed: 0  frame  timestamp   Head Position  \
# 5            5    164       5.44     ['Forward']
# 6            6    202       6.70     ['Forward']
# 7            7    211       6.99     ['Forward']
# 8            8    244       8.10     ['Forward']
# 9            9    282       9.36     ['Forward']
# 10           0    329      10.93  ['Left', 'Up']
# 11           1    359      11.94  ['Left', 'Up']
#
#                                  Objects         Liveliness  \
# 5             ['person', 'bottle', 'tv']           ['Real']
# 6             ['person', 'bottle', 'tv']           ['Real']
# 7             ['person', 'bottle', 'tv']           ['Real']
# 8             ['person', 'bottle', 'tv']           ['Real']
# 9             ['person', 'bottle', 'tv']           ['Real']
# 10  ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 11  ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
#
#                                       Eye Movement Shoulder Movement
# 5     ['Eye Looking left', 'Eye Looking Straight']            Stable
# 6     ['Eye Looking left', 'Eye Looking Downward']            Stable
# 7   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 8   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 9   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 10  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 11    ['Eye Looking left', 'Eye Looking Straight']            Stable

# %%
filter_df_save_frames(hu,video_folder_path,cheating_scenarios,"Head Up")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Up\Frame_164.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Up\Frame_202.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Up\Frame_211.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Up\Frame_244.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Up\Frame_282.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Up\Frame_329.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Head Up\Frame_359.jpg

# %%
df['Eye Movement'].value_counts()
# Out:
# ['Eye Looking Straight']                          23
# ['Eye Looking left', 'Eye Looking Straight']      16
# ['Eye Looking center', 'Eye Looking Straight']    10
# ['Eye Looking left', 'Eye Looking Downward']       6
# ['Eye Looking left', 'Eye Looking Upward']         3
# ['Eye Looking right', 'Eye Looking Downward']      2
# ['Eye Looking center', 'Eye Looking Upward']       1
# ['Eye Looking center', 'Eye Looking Downward']     1
# Name: Eye Movement, dtype: int64

# %%
df.iloc[0:12]
# Out:
#     Unnamed: 0  frame  timestamp      Head Position  \
# 0            0     29       0.93        ['Forward']
# 1            1     33       1.07        ['Forward']
# 2            2     89       2.93        ['Forward']
# 3            3    108       3.57        ['Forward']
# 4            4    141       4.67  ['No Face Found']
# 5            5    164       5.44        ['Forward']
# 6            6    202       6.70        ['Forward']
# 7            7    211       6.99        ['Forward']
# 8            8    244       8.10        ['Forward']
# 9            9    282       9.36        ['Forward']
# 10           0    329      10.93     ['Left', 'Up']
# 11           1    359      11.94     ['Left', 'Up']
#
#                                      Objects         Liveliness  \
# 0       ['person', 'bottle', 'remote', 'tv']           ['Real']
# 1       ['person', 'bottle', 'tv', 'remote']           ['Real']
# 2       ['person', 'bottle', 'tv', 'remote']           ['Real']
# 3   ['person', 'cell phone', 'bottle', 'tv']           ['Real']
# 4       ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 5                 ['person', 'bottle', 'tv']           ['Real']
# 6                 ['person', 'bottle', 'tv']           ['Real']
# 7                 ['person', 'bottle', 'tv']           ['Real']
# 8                 ['person', 'bottle', 'tv']           ['Real']
# 9                 ['person', 'bottle', 'tv']           ['Real']
# 10      ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 11      ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
#
#                                       Eye Movement Shoulder Movement
# 0     ['Eye Looking left', 'Eye Looking Straight']            Stable
# 1     ['Eye Looking left', 'Eye Looking Straight']            Stable
# 2     ['Eye Looking left', 'Eye Looking Straight']            Stable
# 3   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 4                         ['Eye Looking Straight']            Stable
# 5     ['Eye Looking left', 'Eye Looking Straight']            Stable
# 6     ['Eye Looking left', 'Eye Looking Downward']            Stable
# 7   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 8   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 9   ['Eye Looking center', 'Eye Looking Straight']            Stable
# 10  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 11    ['Eye Looking left', 'Eye Looking Straight']            Stable

# %% [markdown]
# ### Eye left

# %%
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Eye Movement'],'left',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
el = df.iloc[idx_list]
el
# Out:
#     Unnamed: 0  frame  timestamp    Head Position  \
# 0            0     29       0.93      ['Forward']
# 16           6    496      16.50      ['Forward']
# 20           0    610      20.30         ['Left']
# 21           1    645      21.47      ['Forward']
# 22           2    672      22.37  ['Right', 'Up']
# 23           3    694      23.10      ['Forward']
# 24           4    729      24.27         ['Down']
# 25           5    751      24.99      ['Forward']
# 26           6    794      26.43      ['Forward']
# 27           7    831      27.66      ['Forward']
# 44           4   1327      44.19      ['Forward']
# 45           5   1352      45.02      ['Forward']
# 46           6   1381      46.00      ['Forward']
# 47           7   1436      47.82      ['Forward']
# 48           8   1466      48.83      ['Forward']
# 49           9   1495      49.79      ['Forward']
# 50           0   1523      50.74      ['Forward']
# 51           1   1552      51.70      ['Forward']
# 52           2   1571      52.34      ['Forward']
# 60           0   1809      60.27      ['Forward']
# 61           1   1836      61.17      ['Forward']
#
#                                               Objects         Liveliness  \
# 0                ['person', 'bottle', 'remote', 'tv']           ['Real']
# 16               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 20               ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 21               ['person', 'bottle', 'remote', 'tv']           ['Real']
# 22               ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 23               ['person', 'bottle', 'remote', 'tv']  ['No Face Found']
# 24               ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 25               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 26                         ['person', 'tv', 'remote']           ['Real']
# 27               ['person', 'bottle', 'tv', 'remote']           ['Real']
# 44           ['person', 'bottle', 'person', 'remote']           ['Real']
# 45  ['person', 'bottle', 'person', 'chair', 'remot...           ['Real']
# 46  ['person', 'bottle', 'person', 'tv', 'remote',...           ['Real']
# 47  ['person', 'bottle', 'toothbrush', 'person', '...           ['Real']
# 48  ['person', 'bottle', 'cell phone', 'person', '...           ['Real']
# 49                 ['person', 'bottle', 'cell phone']           ['Real']
# 50  ['person', 'bottle', 'cell phone', 'person', '...           ['Real']
# 51  ['person', 'bottle', 'chair', 'tv', 'remote', ...           ['Real']
# 52  ['person', 'bottle', 'chair', 'remote', 'tv', ...           ['Real']
# 60  ['person', 'bottle', 'chair', 'tv', 'person', ...           ['Real']
# 61  ['person', 'bottle', 'chair', 'person', 'remot...           ['Real']
#
#                                       Eye Movement Shoulder Movement
# 0     ['Eye Looking left', 'Eye Looking Straight']            Stable
# 16    ['Eye Looking left', 'Eye Looking Downward']            Stable
# 20                        ['Eye Looking Straight']            Stable
# 21  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 22                        ['Eye Looking Straight']            Stable
# 23    ['Eye Looking left', 'Eye Looking Downward']            Stable
# 24                        ['Eye Looking Straight']            Stable
# 25    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 26  ['Eye Looking center', 'Eye Looking Straight']            Stable
# 27    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 44                        ['Eye Looking Straight']            Stable
# 45                        ['Eye Looking Straight']            Stable
# 46  ['Eye Looking center', 'Eye Looking Downward']            Stable
# 47                        ['Eye Looking Straight']            Stable
# 48    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 49    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 50  ['Eye Looking center', 'Eye Looking Straight']            Moving
# 51      ['Eye Looking left', 'Eye Looking Upward']            Stable
# 52    ['Eye Looking left', 'Eye Looking Straight']            Stable
# 60                        ['Eye Looking Straight']            Stable
# 61    ['Eye Looking left', 'Eye Looking Straight']            Stable

# %%
filter_df_save_frames(el,video_folder_path,cheating_scenarios,"Eye Left")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_29.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_496.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_610.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_645.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_672.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_694.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_729.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_751.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_794.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_831.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1327.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1352.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1381.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1436.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1466.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1495.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1523.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1552.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1571.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1809.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Eye Left\Frame_1836.jpg

# %% [markdown]
# ### Eye Right

# %%
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Eye Movement'],'right',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
er = df.iloc[idx_list]
er
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, frame, timestamp, Head Position, Objects, Liveliness, Eye Movement, Shoulder Movement]
# Index: []

# %%
filter_df_save_frames(er,video_folder_path,cheating_scenarios,"Eye Right")

# %% [markdown]
# ### Eye Up

# %%
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Eye Movement'],'Up',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
eu = df.iloc[idx_list]
eu
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, frame, timestamp, Head Position, Objects, Liveliness, Eye Movement, Shoulder Movement]
# Index: []

# %%
filter_df_save_frames(eu,video_folder_path,cheating_scenarios,"Eye Up")

# %% [markdown]
# ### Eye Down

# %%
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Eye Movement'],'Down',i,interval)
    if ratio >= threshold:
        idx_list.append(i)
ed = df.iloc[idx_list]
ed
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, frame, timestamp, Head Position, Objects, Liveliness, Eye Movement, Shoulder Movement]
# Index: []

# %%
filter_df_save_frames(ed,video_folder_path,cheating_scenarios,"Eye Down")

# %%
def get_val_ratio_2(df,cols,vals):
    
    count = 0
    for i,row in df.iterrows():
        status = 1
        for j,c in enumerate(cols):
            if vals[j] in row[cols[j]]:
                status *= 1
            else:
                status *= 0
                
        if status == 1:
            count += 1
            
    return round(count/len(df),2)

# %%
def get_val_ratio_for_interval_2(df,cols,vals,interval_start,num_rows):
    
    df_subset = df.iloc[interval_start:interval_start+num_rows]
    
    return get_val_ratio_2(df,cols,vals)

# %%
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval(df['Eye Movement'].apply(lambda x: "left" in x), True ,i,interval)
    if ratio >= threshold:
        idx_list.append(i)
ssel = df.iloc[idx_list]
ssel
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8428/585521393.py in <module>
#       1 idx_list = []
#       2 for i in df.index:
# ----> 3     ratio = get_val_ratio_for_interval(df['Eye Movement'].apply(lambda x: "left" in x), True ,i,interval)
#       4     if ratio >= threshold:
#       5         idx_list.append(i)
#
# ~\AppData\Local\Temp/ipykernel_8428/3492590755.py in get_val_ratio_for_interval(col, val, interval_start, num_rows)
#       2     col_subset = col.iloc[interval_start:interval_start+num_rows]
#       3
# ----> 4     return get_val_ratio(col_subset,val)
#
# ~\AppData\Local\Temp/ipykernel_8428/4216213194.py in get_val_ratio(col, val)
#       2     c = 0
#       3     for row in col:
# ----> 4         if val in row:
#       5             c += 1
#       6
#
# TypeError: argument of type 'bool' is not iterable

# %% [markdown]
# ### Shoulder Stable Eye Left

# %%
idx_list = []
for i in df.index:
    ratio = get_val_ratio_for_interval((df['Eye Movement'].apply(lambda x: "left" in x)) & (df['Shoulder Movement'].apply(lambda x: "Stable" in x)), True i,interval)
    if ratio >= threshold:
        idx_list.append(i)
ssel = df.iloc[idx_list]
ssel
# Out:
#   File "C:\Users\lenovo\AppData\Local\Temp/ipykernel_8428/2673334960.py", line 3
#     ratio = get_val_ratio_for_interval((df['Eye Movement'].apply(lambda x: "left" in x)) & (df['Shoulder Movement'].apply(lambda x: "Stable" in x)), True i,interval)
#                                                                                                                                                           ^
# SyntaxError: invalid syntax

# %%
filter_df_save_frames(ssel,video_folder_path,cheating_scenarios,"Shoulders Stable Eye Left")
# Out:
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_29.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_33.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_89.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_164.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_202.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_359.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_496.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_511.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_548.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_694.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_751.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_831.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_854.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_874.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_945.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_966.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_1286.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_1466.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_1495.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_1552.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_1571.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_1607.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_1646.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_1657.jpg
# Frame Saved at C:\Users\lenovo\Documents\Ai Proctor Integration Version 4\WIN_20211118_17_49_03_Pro\Cheating Scenarios\Shoulders Stable Eye Left\Frame_1836.jpg

# %% [markdown]
# ### Shoulders Stable Eye Right

# %%
sser = df.loc[(df['Eye Movement'].apply(lambda x: "right" in x)) & (df['Shoulder Movement'] == 'Stable')]
sser
# Out:
#     Unnamed: 0  frame  timestamp   Head Position  \
# 12           2    383      12.74  ['Left', 'Up']
# 30           0    902      30.03        ['Left']
#
#                                            Objects         Liveliness  \
# 12            ['person', 'bottle', 'tv', 'remote']  ['No Face Found']
# 30  ['person', 'person', 'bottle', 'remote', 'tv']  ['No Face Found']
#
#                                      Eye Movement Shoulder Movement
# 12  ['Eye Looking right', 'Eye Looking Downward']            Stable
# 30  ['Eye Looking right', 'Eye Looking Downward']            Stable
